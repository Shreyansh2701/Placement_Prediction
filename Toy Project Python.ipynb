# %% [markdown]
# # Toy Project

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/placement.csv');

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['cgpa'].plot(kind='hist', bins=20, title='cgpa')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['iq'].plot(kind='hist', bins=20, title='iq')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['placement'].plot(kind='hist', bins=20, title='placement')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3.plot(kind='scatter', x='cgpa', y='iq', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='iq', y='placement', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5['cgpa'].plot(kind='line', figsize=(8, 4), title='cgpa')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6['iq'].plot(kind='line', figsize=(8, 4), title='iq')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7['placement'].plot(kind='line', figsize=(8, 4), title='placement')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'], df['iq'], c=df['placement'])

# %%
x = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train, y_test = train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 82   6.5   37.0
# 87   5.7  132.0
# 40   4.9  134.0
# 14   6.1  103.0
# 53   8.3  168.0
# ..   ...    ...
# 94   4.7   52.0
# 21   7.1  151.0
# 48   6.6  138.0
# 84   5.7  169.0
# 30   7.6  128.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 82    1
# 87    1
# 40    0
# 14    0
# 53    1
#      ..
# 94    0
# 21    1
# 48    1
# 84    0
# 30    1
# Name: placement, Length: 90, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 4.39277015e-01, -2.18694270e+00],
#        [-2.76287353e-01,  2.31052914e-01],
#        [-9.91851722e-01,  2.81958085e-01],
#        [ 8.14948309e-02, -5.07072062e-01],
#        [ 2.04929684e+00,  1.14734599e+00],
#        [ 1.15484138e+00,  3.58315841e-01],
#        [-6.34069538e-01, -2.27093623e-01],
#        [ 7.97059199e-01,  4.09221012e-01],
#        [-1.08129727e+00,  1.02008306e+00],
#        [ 2.22818794e+00, -7.43781106e-02],
#        [ 7.07613653e-01, -8.37955672e-01],
#        [-5.44623992e-01,  4.09221012e-01],
#        [ 1.33373248e+00, -1.57608065e+00],
#        [-9.02406176e-01, -8.12503087e-01],
#        [ 9.75950292e-01, -1.90696426e+00],
#        [-2.76287353e-01,  5.11031353e-01],
#        [ 1.15484138e+00, -1.76188452e-01],
#        [-7.95071521e-03, -1.98332201e+00],
#        [-5.44623992e-01, -2.27093623e-01],
#        [-1.43907945e+00, -2.05967977e+00],
#        [ 7.07613653e-01, -2.77998794e-01],
#        [ 1.42317802e+00, -8.63408257e-01],
#        [-7.23515084e-01,  9.69177890e-01],
#        [-7.23515084e-01, -8.37955672e-01],
#        [-2.76287353e-01,  4.34673597e-01],
#        [-9.02406176e-01, -1.52517548e+00],
#        [ 7.07613653e-01,  1.97964553e-03],
#        [ 1.33373248e+00,  1.80147743e-01],
#        [ 1.60206911e+00, -2.27093623e-01],
#        [-6.34069538e-01, -4.89255252e-02],
#        [-1.08129727e+00,  4.60126182e-01],
#        [ 8.86504745e-01,  4.09221012e-01],
#        [-1.88630718e+00, -3.54356550e-01],
#        [ 4.39277015e-01,  1.80147743e-01],
#        [-2.24408937e+00,  2.80176404e+00],
#        [-9.91851722e-01, -1.57608065e+00],
#        [-9.91851722e-01,  1.86001838e+00],
#        [-7.95071521e-03,  6.63746865e-01],
#        [-1.86841807e-01,  1.09644082e+00],
#        [-7.23515084e-01,  2.57269077e+00],
#        [ 1.33373248e+00,  8.92820134e-01],
#        [ 3.49831469e-01, -1.76188452e-01],
#        [ 1.15484138e+00, -9.39766014e-01],
#        [-1.08129727e+00, -2.77998794e-01],
#        [ 8.14948309e-02, -1.06702894e+00],
#        [-9.91851722e-01, -7.43781106e-02],
#        [-1.26018836e+00,  5.87389109e-01],
#        [-7.23515084e-01, -3.28903964e-01],
#        [ 7.97059199e-01, -6.85240160e-01],
#        [ 4.39277015e-01,  9.43725305e-01],
#        [ 7.97059199e-01,  3.83768426e-01],
#        [-1.08129727e+00,  1.17279857e+00],
#        [-2.42298046e+00,  1.52913477e+00],
#        [-7.95071521e-03,  2.74322309e-02],
#        [-1.79686164e+00, -1.21974445e+00],
#        [-1.17074281e+00, -4.89255252e-02],
#        [-5.44623992e-01,  3.07410670e-01],
#        [-8.12960630e-01, -1.44881772e+00],
#        [ 6.18168107e-01,  7.91009792e-01],
#        [-1.17074281e+00, -9.14313428e-01],
#        [-7.95071521e-03, -1.44881772e+00],
#        [ 8.14948309e-02,  8.41914963e-01],
#        [ 5.28722561e-01, -7.43781106e-02],
#        [ 2.60385923e-01,  1.29242572e-01],
#        [-1.43907945e+00,  6.63746865e-01],
#        [ 3.49831469e-01,  4.60126182e-01],
#        [ 1.87040575e+00,  6.63746865e-01],
#        [-9.73962613e-02, -4.30714306e-01],
#        [ 8.14948309e-02, -1.47427031e+00],
#        [ 8.86504745e-01,  1.32551409e+00],
#        [-1.86841807e-01,  4.85578768e-01],
#        [-7.23515084e-01,  2.31052914e-01],
#        [ 8.86504745e-01, -1.49972289e+00],
#        [-8.12960630e-01,  1.29242572e-01],
#        [ 2.60385923e-01,  1.03789987e-01],
#        [ 1.70940377e-01, -2.52546208e-01],
#        [-9.91851722e-01,  8.16462378e-01],
#        [ 1.24428693e+00,  2.31052914e-01],
#        [-5.44623992e-01, -4.05261721e-01],
#        [ 1.78096021e+00, -1.11793411e+00],
#        [ 8.86504745e-01, -2.77998794e-01],
#        [ 8.86504745e-01,  1.93637613e+00],
#        [-7.95071521e-03, -5.32524647e-01],
#        [ 8.14948309e-02,  2.31052914e-01],
#        [ 6.18168107e-01,  1.50368218e+00],
#        [-1.17074281e+00, -1.80515392e+00],
#        [ 9.75950292e-01,  7.14652036e-01],
#        [ 5.28722561e-01,  3.83768426e-01],
#        [-2.76287353e-01,  1.17279857e+00],
#        [ 1.42317802e+00,  1.29242572e-01]])

# %%
x_test = scaler.transform(x_test)

# %%
x_test
# Out:
# array([[ 1.87040575,  1.09644082],
#        [-0.90240618, -0.12528328],
#        [-1.528525  ,  1.96182872],
#        [ 0.43927702, -0.83795567],
#        [-1.79686164, -0.58342982],
#        [ 0.26038592, -0.50707206],
#        [-0.99185172,  0.71465204],
#        [ 0.70761365,  0.46012618],
#        [ 1.15484138, -1.85605909],
#        [-0.81296063,  1.35096667]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
# model training
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(x_test)

# %%
y_test
# Out:
# 65    1
# 67    0
# 95    0
# 79    1
# 18    0
# 98    1
# 89    0
# 43    1
# 77    1
# 15    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf, open('model.pkl', 'wb'))

# %% [markdown]
# ## Steps
#
# 1. PreProcess + EDA + Feature Selection
# 2. Extract input and output columns
# 3. Scale the values
# 4. Train test split
# 5. Train the model
# 6. Evaluate the model/ model selection
# 7. Deploy the model
